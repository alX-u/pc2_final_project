# %%
# !pip install SQLAlchemy 
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: SQLAlchemy in /opt/conda/lib/python3.9/site-packages (1.4.27)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from SQLAlchemy) (1.1.2)
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.9/site-packages (2.9.2)

# %%
import psycopg2 as pg
import pandas as pd

# %% [markdown]
# We connect to the database:

# %%
conn = pg.connect(host='postgres', database='postgres', user='postgres', password='postgres')

# %% [markdown]
# Visualizations:

# %%
dataframe = pd.read_sql("SELECT * FROM data_src", conn)

# %%
dataframe
# Out:
#     datasrc_id                                   authors  \
# 0       D1066                                  G.V. Mann
# 1       D1073                 J.P. McBride, R.A. Maclead
# 2       D1107                               M.E. Stansby
# 3       D1191                   I.J. Tinsley, R.R. Lowry
# 4       D1243                      M. Iwasaki, R. Harada
# ..         ...                                       ...
# 361     S9      Food and Drug Administration (FDA), DHHS
# 362     S941                    Hammons Products Company
# 363     S961              National Sunflower Association
# 364     S963         Produce Marketing Association (PMA)
# 365     S986                         University of Maine
#
#                                                  title    year  \
# 0    The Health and Nutritional status of Alaskan E...  1962.0
# 1    Sodium and potassium in fish from the Canadian...  1956.0
# 2    Chemical Characteristics of fish caught in the...  1976.0
# 3        Bromine content of lipids of marine organisms  1980.0
# 4               Composition of the Ros Marine Species.  1985.0
# ..                                                 ...     ...
# 361                               FDA Total Diet Study  1994.0
# 362                 Nutrient Analysis of Black Walnuts  2002.0
# 363   Nutrient Analysis of Oil Roasted Sunflower Seeds  2000.0
# 364                    Nutrient Content of Raspberries  1990.0
# 365  Determination of alpha- and beta-carotene in f...  1982.0
#
#                                           journal  vol_city issue_state  \
# 0          American Journal of Clinical Nutrition        11
# 1    Journal of the American Dietetic Association        32
# 2                                Marine Fish Rev.        38           9
# 3         American Oil Chemists' Society, Journal                     1
# 4                          (Pre-publication copy)
# ..                                            ...       ...         ...
# 361
# 362                                                Stockton          MO
# 363                                                 Bismark          ND
# 364
# 365
#
#     start_page end_page
# 0           31       76
# 1          636      638
# 2            1       11
# 3           31       33
# 4
# ..         ...      ...
# 361
# 362
# 363
# 364
# 365
#
# [366 rows x 9 columns]
